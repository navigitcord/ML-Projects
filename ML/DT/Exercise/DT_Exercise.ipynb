# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
meanv =df['Age'].median()
df['Age'].fillna(value=meanv, inplace=True)
df = np.round(df, decimals = 0)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
inputs = df.drop(['PassengerId','Name','SibSp','Ticket','Cabin','Embarked','Survived'],axis=1)
inputs
# Out:
#      Pclass     Sex   Age  Parch  Fare
# 0         3    male  22.0      0   7.0
# 1         1  female  38.0      0  71.0
# 2         3  female  26.0      0   8.0
# 3         1  female  35.0      0  53.0
# 4         3    male  35.0      0   8.0
# ..      ...     ...   ...    ...   ...
# 886       2    male  27.0      0  13.0
# 887       1  female  19.0      0  30.0
# 888       3  female  28.0      2  23.0
# 889       1    male  26.0      0  30.0
# 890       3    male  32.0      0   8.0
#
# [891 rows x 5 columns]

# %%
target = df['Survived']
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le_sex = LabelEncoder()

# %%
inputs['sex_n'] = le_sex.fit_transform(inputs['Sex'])

# %%
inputs
# Out:
#      Pclass     Sex   Age  Parch  Fare  sex_n
# 0         3    male  22.0      0   7.0      1
# 1         1  female  38.0      0  71.0      0
# 2         3  female  26.0      0   8.0      0
# 3         1  female  35.0      0  53.0      0
# 4         3    male  35.0      0   8.0      1
# ..      ...     ...   ...    ...   ...    ...
# 886       2    male  27.0      0  13.0      1
# 887       1  female  19.0      0  30.0      0
# 888       3  female  28.0      2  23.0      0
# 889       1    male  26.0      0  30.0      1
# 890       3    male  32.0      0   8.0      1
#
# [891 rows x 6 columns]

# %%
inputs_n = inputs.drop(['Sex','Fare'],axis='columns')
inputs_n
# Out:
#      Pclass   Age  Parch  sex_n
# 0         3  22.0      0      1
# 1         1  38.0      0      0
# 2         3  26.0      0      0
# 3         1  35.0      0      0
# 4         3  35.0      0      1
# ..      ...   ...    ...    ...
# 886       2  27.0      0      1
# 887       1  19.0      0      0
# 888       3  28.0      2      0
# 889       1  26.0      0      1
# 890       3  32.0      0      1
#
# [891 rows x 4 columns]

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
model.fit(inputs_n, target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(inputs_n,target)
# Out:
# 0.9012345679012346

# %%
model.predict([[3,22,0,1]])
# Out:
# C:\Users\navne\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
model.predict([[1,38,0,0]])
# Out:
# C:\Users\navne\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
'''In this file using following columns build a model to predict if person would survive or not,
Pclass
Sex
Age
Fare
Calculate score of your model'''
